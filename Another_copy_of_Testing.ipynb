# %% [markdown]
# <a href="https://colab.research.google.com/github/YeoBengWah/my-first-data-journal/blob/main/Another_copy_of_Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, GitHub! This is my first commit.")
print("On 20 Feb 2026")
# Out:
# Hello, GitHub! This is my first commit.
# On 20 Feb 2026
