# %% [markdown]
# <a href="https://colab.research.google.com/github/YeoBengWah/my-first-data-journal/blob/main/Exercise_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, GitHub! This is my first commit.")
# Out:
# Hello, GitHub! This is my first commit.
